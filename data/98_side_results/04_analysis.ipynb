# %% [markdown]
# # Imports

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)  # None means no limit

# %% [markdown]
# # Import Topics DF
# ## (Results from BERTopic)

# %%
topics_df = pd.read_csv('BERTopic_results.csv')
topics_df = topics_df.drop(0) # drop cluster -1 from df

# %% [markdown]
# # Add Clusters & Content Similarities

# %%
cluster_df = pd.read_csv('clustering_results.csv')
categorized_df = pd.read_csv('../04_categorized_data/similarity_scored_paragraphs.csv')

cluster_df = cluster_df.reset_index(drop=True)
categorized_df = categorized_df.reset_index(drop=True)

# Merge the DataFrames on index
merged_df = pd.merge(cluster_df, categorized_df, left_index=True, right_index=True)

# %%
average_similarity = merged_df.groupby('cluster_x')['similarity_score'].mean().reset_index()

average_cat_sim_list = []

for i in range(1, 8):
    # Sort the DataFrame by 'similarity_score' in descending order
    average_sim = merged_df.groupby('cluster_x')[f'similarity_score_{i}'].mean().reset_index()
    average_cat_sim_list.append(average_sim)

# %%
# Merge topics_df with the average_similarity DataFrame
topics_df = pd.merge(topics_df, average_similarity, left_on='Topic', right_on='cluster_x', how='inner')
topics_df['avg_content_similarity'] = topics_df['similarity_score']
topics_df = topics_df.drop(columns=['similarity_score', 'cluster_x'])

# Merge with the category-specific similarity DataFrames
for i in range(1, 8):
    topics_df = pd.merge(topics_df, average_cat_sim_list[i-1], left_on='Topic', right_on='cluster_x', how='inner')
    topics_df[f'avg_cat{i}_similarity'] = topics_df[f'similarity_score_{i}']
    topics_df = topics_df.drop(columns=[f'similarity_score_{i}', 'cluster_x'])

# %% [markdown]
# # Add Centroids

# %%
centroids_df = pd.read_csv('centroid_analysis_results.csv')

euclidean_df = centroids_df[centroids_df['ranking_type'] == 'euclidean'].copy()
cosine_df = centroids_df[centroids_df['ranking_type'] == 'cosine'].copy()

# %%
# Euclidean Distance

# Sort the DataFrame by 'cluster' and 'distance_to_centroid' in ascending order
euclidean_df_sorted = euclidean_df.sort_values(by=['cluster', 'distance_to_centroid'], ascending=[True, True])

# Group by 'cluster' and take the top 3 rows with the lowest 'distance_to_centroid' for each group
top_3_lowest_distance_per_cluster = euclidean_df_sorted.groupby('cluster').head(3).reset_index(drop=True)

# %%
# Cosine Similarity

# Sort the DataFrame by 'cluster' and 'distance_to_centroid' in ascending order
cosine_df_sorted = cosine_df.sort_values(by=['cluster', 'cosine_similarity_to_centroid'], ascending=[True, False])

# Group by 'cluster' and take the top 3 rows with the lowest 'distance_to_centroid' for each group
top_3_highest_cosim_per_cluster = cosine_df_sorted.groupby('cluster').head(3).reset_index(drop=True)

# %% [markdown]
# # Prepare final DataFrame

# %%
# Initialize new columns in topics_df
topics_df['euclidean_1'] = ''
topics_df['euclidean_1_distance'] = ''
topics_df['euclidean_2'] = ''
topics_df['euclidean_2_distance'] = ''
topics_df['euclidean_3'] = ''
topics_df['euclidean_3_distance'] = ''
topics_df['cosine_1'] = ''
topics_df['cosine_1_similarity'] = ''
topics_df['cosine_2'] = ''
topics_df['cosine_2_similarity'] = ''
topics_df['cosine_3'] = ''
topics_df['cosine_3_similarity'] = ''

# Group the top_3_lowest_distance_per_cluster by 'cluster' to facilitate adding text and distance
grouped_euclidean = top_3_lowest_distance_per_cluster.groupby('cluster')

# Iterate over each cluster in top_3_lowest_distance_per_cluster
for cluster, group in grouped_euclidean:
    texts = group['text'].tolist()
    distances = group['distance_to_centroid'].tolist()

    # Find the corresponding row in topics_df and assign the text and distance values
    if len(texts) >= 1:
        topics_df.loc[topics_df['Topic'] == cluster, 'euclidean_1'] = texts[0]
        topics_df.loc[topics_df['Topic'] == cluster, 'euclidean_1_distance'] = distances[0]
    if len(texts) >= 2:
        topics_df.loc[topics_df['Topic'] == cluster, 'euclidean_2'] = texts[1]
        topics_df.loc[topics_df['Topic'] == cluster, 'euclidean_2_distance'] = distances[1]
    if len(texts) >= 3:
        topics_df.loc[topics_df['Topic'] == cluster, 'euclidean_3'] = texts[2]
        topics_df.loc[topics_df['Topic'] == cluster, 'euclidean_3_distance'] = distances[2]

# Group the top_3_highest_cosim_per_cluster by 'cluster' to facilitate adding text and similarity
grouped_cosine = top_3_highest_cosim_per_cluster.groupby('cluster')

# Iterate over each cluster in top_3_highest_cosim_per_cluster
for cluster, group in grouped_cosine:
    texts = group['text'].tolist()
    similarities = group['cosine_similarity_to_centroid'].tolist()

    # Find the corresponding row in topics_df and assign the text and similarity values
    if len(texts) >= 1:
        topics_df.loc[topics_df['Topic'] == cluster, 'cosine_1'] = texts[0]
        topics_df.loc[topics_df['Topic'] == cluster, 'cosine_1_similarity'] = similarities[0]
    if len(texts) >= 2:
        topics_df.loc[topics_df['Topic'] == cluster, 'cosine_2'] = texts[1]
        topics_df.loc[topics_df['Topic'] == cluster, 'cosine_2_similarity'] = similarities[1]
    if len(texts) >= 3:
        topics_df.loc[topics_df['Topic'] == cluster, 'cosine_3'] = texts[2]
        topics_df.loc[topics_df['Topic'] == cluster, 'cosine_3_similarity'] = similarities[2]

# %%
# Sort by Content Similarity

sorted_df = topics_df.sort_values(by=['avg_content_similarity'], ascending=[False])

# Select relevant columns

selected_df = sorted_df[['Name', 'Representative_Docs', 'avg_content_similarity', 'avg_cat1_similarity', 'avg_cat2_similarity',
       'avg_cat3_similarity', 'avg_cat4_similarity', 'avg_cat5_similarity',
       'avg_cat6_similarity', 'avg_cat7_similarity',]]

# %% [markdown]
# ## Analyze Results

# %% [markdown]
# Here we try to find topics with a high similarity score in one of the categories and low similarity scores in all others.

# %%
similarity_cols = [f"avg_cat{i}_similarity" for i in range(1,8)]

threshold_high = 0.9
threshold_low = 0.85

# Count how many columns are "high" for each row
high_mask = (topics_df[similarity_cols] > threshold_high).sum(axis=1)

# Count how many columns are "low" for each row
low_mask = (topics_df[similarity_cols] < threshold_low).sum(axis=1)

# We want exactly 1 column above threshold_high,
# and the other 6 columns below threshold_low
condition = (high_mask == 1) & (low_mask == 6)

filtered_df = topics_df[condition]
filtered_df.head(20)
# Out:
#      Topic  Count                                               Name  \
# 440    440    146  440_gesundheitskosten_salaire_gesundheitskommi...
# 497    497    134                      497_patient_patienten_akut_75
#
#                                         Representation  \
# 440  ['gesundheitskosten', 'salaire', 'gesundheitsk...
# 497  ['patient', 'patienten', 'akut', '75', '87000'...
#
#                                    Representative_Docs  \
# 440  ['Angesichts der explodierenden Gesundheitskos...
# 497  ['Die Auslastung der Intensivstationen in den ...
#
#                                            euclidean_1 euclidean_1_distance  \
# 440  Es ist zum Sinnbild geworden, für alles, das s...             0.749098
# 497  4 In Gebieten, in die noch nicht so viel Geld ...             0.770335
#
#                                            euclidean_2 euclidean_2_distance  \
# 440  Die Pandemie zeige die Schwachstellen unseres ...             0.983157
# 497  Davon würden laut Buholzer alle profitieren: D...             0.776786
#
#                                            euclidean_3  ...  \
# 440  Der Fax verkam während der Pandemie zum Sinnbi...  ...
# 497  Das muss sich jetzt ändern. Das jedenfalls for...  ...
#
#                                               cosine_3 cosine_3_similarity  \
# 440  10:07 Pandemie zeigt Lücken bei der Digitalisi...            0.485742
# 497  Es spricht vieles dafür, dass der Wert der med...            0.677046
#
#     avg_content_similarity avg_cat1_similarity avg_cat2_similarity  \
# 440               0.806149            0.844976            0.818339
# 497               0.805398            0.838464            0.815531
#
#     avg_cat3_similarity avg_cat4_similarity  avg_cat5_similarity  \
# 440            0.829608            0.828727             0.839351
# 497            0.829176            0.843110             0.833660
#
#      avg_cat6_similarity  avg_cat7_similarity
# 440             0.901993             0.809923
# 497             0.900238             0.808341
#
# [2 rows x 25 columns]

# %% [markdown]
# Here we list the 20 Topics with the highest variance between similarity to two different categories.

# %%
similarity_cols = [f"avg_cat{i}_similarity" for i in range(1,8)]

# Calculate the difference between the max and min similarity in each row
topics_df["max_diff"] = topics_df[similarity_cols].max(axis=1) - topics_df[similarity_cols].min(axis=1)

# Sort by max_diff descending, so the rows with the biggest spread are at the top
topics_df.sort_values(by="max_diff", ascending=False, inplace=True)

# Now topics_df is sorted, and the first rows have the largest delta
topics_df.head(20)
# Out:
#      Topic  Count                                               Name  \
# 303    303    199              303_infizierten_italien_virus_gezählt
# 233    233    228      233_gestorben_décédée_italiens_brasilianische
# 346    346    176              346_traurig_schrecklich_frère_sterben
# 410    410    155  410_erschossen_geschossen_angeschossen_angesch...
# 186    186    274        186_zivilen_schutz_sicherheit_uniformierten
# 222    222    236           222_entlassen_minister_general_präsident
# 431    431    150  431_öffentlich_unumgänglich_zugänglichen_sport...
# 347    347    176  347_marktführendes_marktbreite_konjunktursensi...
# 370    370    168  370_übergewichtigen_übergewichtige_übergewicht...
# 312    312    192               312_getesteten_tests_testen_getestet
# 423    423    151  423_coronavirus_epidemiologischen_erkrankten_g...
# 161    161    294  161_alcoolisation_alkoholische_alcoolique_alcools
# 214    214    246                     214_hospitalisations_97_100_87
# 204    204    256      204_transgender_trans_transidente_bisexuellen
# 413    413    154  413_slowakischen_angeschossen_slowakische_getr...
# 273    273    212         273_verletzte_verletzt_verletzungen_spital
# 160    160    295                 160_russische_getroffen_1941_krieg
# 206    206    255  206_gesundheitsförderliche_gesundheit_medizin_...
# 379    379    164   379_infizierten_infizierte_hospitalisiert_spital
# 320    320    189  320_afroamerikanische_afroamerikanischen_rassi...
#
#                                         Representation  \
# 303  ['infizierten', 'italien', 'virus', 'gezählt',...
# 233  ['gestorben', 'décédée', 'italiens', 'brasilia...
# 346  ['traurig', 'schrecklich', 'frère', 'sterben',...
# 410  ['erschossen', 'geschossen', 'angeschossen', '...
# 186  ['zivilen', 'schutz', 'sicherheit', 'uniformie...
# 222  ['entlassen', 'minister', 'general', 'präsiden...
# 431  ['öffentlich', 'unumgänglich', 'zugänglichen',...
# 347  ['marktführendes', 'marktbreite', 'konjunkturs...
# 370  ['übergewichtigen', 'übergewichtige', 'übergew...
# 312  ['getesteten', 'tests', 'testen', 'getestet', ...
# 423  ['coronavirus', 'epidemiologischen', 'erkrankt...
# 161  ['alcoolisation', 'alkoholische', 'alcoolique'...
# 214  ['hospitalisations', '97', '100', '87', '71', ...
# 204  ['transgender', 'trans', 'transidente', 'bisex...
# 413  ['slowakischen', 'angeschossen', 'slowakische'...
# 273  ['verletzte', 'verletzt', 'verletzungen', 'spi...
# 160  ['russische', 'getroffen', '1941', 'krieg', 'n...
# 206  ['gesundheitsförderliche', 'gesundheit', 'medi...
# 379  ['infizierten', 'infizierte', 'hospitalisiert'...
# 320  ['afroamerikanische', 'afroamerikanischen', 'r...
#
#                                    Representative_Docs  \
# 303  ["21:57 Italien: 7-Tage-Inzidenz ist gesunken ...
# 233  ['Italiens Fussball trauert um einen seiner eh...
# 346  ['L’infirmier en soins intensifs qui conduit l...
# 410  ['Winterthur Ein 70-jähriger Mann hat sich am ...
# 186  ['Dass sich Spezialkräfte als medizinisches Pe...
# 222  ['Zu Jahresbeginn war der Minister in die Krit...
# 431  ['Vom 6. August an werden viele soziale, kultu...
# 347  ['Die Lage am US-Arbeitsmarkt verbessert sich,...
# 370  ['Aktuell sind in der Schweiz mehr als 17 Proz...
# 312  ['Bis anhin hat der Bund Tests von Menschen oh...
# 423  ["14:44 7-Tage-Schnitt der Neuinfektionen weit...
# 161  ['Als besonders gefährlich erachten die Expert...
# 214  ['Wie«finews.ch»berichtete, wiesen die beiden ...
# 204  ['Sie können lediglich über die Anzahl Patient...
# 413  ['Der slowakische Regierungschef Robert Fico i...
# 273  ['Der 16-Jähriger war am Freitag, gegen 23.30 ...
# 160  ['Bis am 30. März ging die Zerstörung noch wei...
# 206  ['Gesundheitsförderung Uri', 'Gesundheitsförde...
# 379  ['23 Infizierte befinden sich aktuell im Spita...
# 320  ['Es gibt viele Gründe dafür, dass Menschen in...
#
#                                            euclidean_1 euclidean_1_distance  \
# 303  >> Lire:L'Hôpital de La Chaux-de-Fonds aura so...             1.270584
# 233  Seit Anfang Jahr findet einmal im Monat in Flü...               1.1099
# 346  Thun Die Spital STS AG lädt zum nächsten Vortr...             1.094006
# 410  Die St.Galler Spitäler kommen nicht zur Ruhe. ...             0.948056
# 186  Mit Entsetzen lese ich in der bz, dassTamedia ...             0.949019
# 222  Angehörige und Patienten hätten erstaunlich vi...             1.079002
# 431  Der Infektiologe Fabian Tschumi ist Leitender ...             0.962318
# 347  Das Kantonsspital Aarau (KSA) hat der Hirsland...             0.798135
# 370  Ces revêtements autodésinfectants utilisés pou...             1.005808
# 312  Und dann fing er an, die künstliche Bandscheib...             1.281987
# 423  Der 60-jährige Thierry Carrel ist Direktor der...             1.140084
# 161  «Zur Entspannung können solche Tiktoks durchau...             0.864769
# 214  Chefarzt Georg Schulthess, sein Ärzteteam und ...             1.068359
# 204  Heart-Team – auf dieses Wort verzichtet kaum e...              1.10464
# 413  Zum Schutz von Patientinnen und Patienten: In ...             0.743104
# 273  Zunächst einmal gibt es gar nicht genug Dermat...             0.662802
# 160  Wie Christian Schär, Präsident des Verbands de...             0.829167
# 206  Bei vielen schwer an Covid-19-Erkrankten in Sc...             1.289199
# 379  Das Pilotprojekt der RehaClinic und des Spital...             1.016204
# 320  Der Kanton Thurgau und die Spital Thurgau AG a...             1.003422
#
#                                            euclidean_2 euclidean_2_distance  \
# 303  Mit seiner Forschung schuf Richard Ernst auch ...             1.296072
# 233  Brustkrebs Das Kantonsspital Baden und das Spi...             1.129966
# 346  Herisau Im Rahmen eines öffentlichen Vortrags ...             1.121901
# 410  Doch gerade bei der Herzchirurgie ziehen das d...             1.126188
# 186  Eine Klinik im US-Bundesstaat Kalifornien muss...             0.963453
# 222  beantwortet. Wie mag es jemandem gehen, der na...             1.275854
# 431  Infektiologe Fabian Tschumi ist Leitender Arzt...             1.111013
# 347  Laut Kennern des Gesundheitswesens wäre es nic...              1.13368
# 370  Die Tagesklinik des Spitals Muri hat den tradi...             1.096899
# 312  Und in der Schweiz? Recherchen zeigen, dass im...             1.327687
# 423  Operationen nach den gleichen Standards, aber ...             1.250157
# 161  Ursula Speck ist Oberärztin im Interdisziplinä...             1.652732
# 214  Das Unispital führt interne Pools mit Mitarbei...             1.347127
# 204  Welches Unternehmen für den Transport des Herz...             1.365312
# 413  Nun ist also so weit, sogar in den Läden muss ...             0.828059
# 273  C’est au début des années 90 que l’on a vu app...             0.909291
# 160  Ein neuer Begriff macht im Berner Gesundheitsw...             1.092185
# 206  Marodes Gesundheitssystem: Klinik für Infektio...             1.400467
# 379  Die Reha-Clinic aus Bad Zurzach (im Bild) eröf...             1.462075
# 320  Mit dem Ziel, ein gemeinsames Vorgehen im Umga...             1.040212
#
#                                            euclidean_3  ...  \
# 303  Depuis le début de l'année, des interventions ...  ...
# 233  THUN Die rosa Schleife ist das internationale ...  ...
# 346  Burgdorf Der nächste Publikumsvortrag im Spita...  ...
# 410  Es ist aussergewöhnlich, dass die beiden Verbä...  ...
# 186  Ab Mitte Mai soll Da Vinci in der Viszeralchir...  ...
# 222  Die Akutbehandlung im Spital von Patienten in ...  ...
# 431  Andrée Friedli, Infektiologin am Kantonsspital...  ...
# 347  Seit einer Woche ist bekannt, dass das Kantons...  ...
# 370  Auch die anderen Spitäler setzen auf zusätzlic...  ...
# 312  Die Staatsanwaltschaft des Kantons Bern ermitt...  ...
# 423  Zuvor hiess es vonseiten der Insel stets, nur ...  ...
# 161  Roland Wiederkehr ist deshalb überzeugt, dass ...  ...
# 214  Auch die Spitäler in beiden Basel erleben dies...  ...
# 204  Dank der Aufteilung in mehrere Tranchen musste...  ...
# 413  In der Kita tragen seit Corona alle Mitarbeite...  ...
# 273  Ainsi que nous l’indique le Dr Arthur Hammer, ...  ...
# 160  Ist dieser (oder sein Vertreter) nicht erreich...  ...
# 206  In Griechenland sind die Spitäler überlastet, ...  ...
# 379  00:12:32In Winterthur er soll es eine neue Reh...  ...
# 320  Am Mittwoch teilt das Kantonsspital Obwalden m...  ...
#
#     cosine_3_similarity avg_content_similarity avg_cat1_similarity  \
# 303             0.70003               0.388634            0.440701
# 233            0.418718               0.276179            0.326903
# 346             0.66641               0.022363            0.046084
# 410            0.675895               0.194357            0.209326
# 186            0.464433               0.374627            0.428201
# 222            0.590145               0.432292            0.487080
# 431            0.654728              -0.307012           -0.282337
# 347            0.907997               0.324993            0.336395
# 370             0.44013               0.077153            0.153066
# 312            0.547828              -0.169485           -0.136308
# 423            0.423208              -0.146485           -0.140644
# 161            0.655144               0.002797            0.050313
# 214            0.432218               0.490078            0.540949
# 204            0.752346               0.322523            0.339482
# 413            0.707578               0.080047            0.145402
# 273            0.418828               0.286614            0.346670
# 160            0.432291              -0.063363           -0.015689
# 206            0.692122               0.310622            0.345657
# 379             0.63465               0.389792            0.416251
# 320            0.537573              -0.028892            0.036390
#
#     avg_cat2_similarity avg_cat3_similarity avg_cat4_similarity  \
# 303            0.382510            0.413754            0.447440
# 233            0.280459            0.296919            0.335842
# 346           -0.037347            0.048786            0.073912
# 410            0.121521            0.195120            0.261731
# 186            0.376501            0.394929            0.427229
# 222            0.448848            0.498458            0.485253
# 431           -0.378308           -0.299699           -0.289340
# 347            0.250746            0.327829            0.387918
# 370            0.129148            0.147239            0.054801
# 312           -0.189338           -0.171111           -0.096824
# 423           -0.218129           -0.152982           -0.076125
# 161            0.037328            0.033543            0.073669
# 214            0.481808            0.543931            0.505317
# 204            0.277304            0.343406            0.411920
# 413            0.098209            0.135503            0.032913
# 273            0.316389            0.320241            0.328192
# 160           -0.062783            0.008622           -0.015758
# 206            0.352865            0.320997            0.196527
# 379            0.330674            0.415060            0.409884
# 320           -0.008074            0.049818           -0.048534
#
#     avg_cat5_similarity  avg_cat6_similarity  avg_cat7_similarity  max_diff
# 303            0.417043             0.559691             0.374814  0.184877
# 233            0.310601             0.448001             0.266953  0.181048
# 346            0.011334             0.142534            -0.025641  0.179881
# 410            0.177715             0.300134             0.139808  0.178614
# 186            0.404751             0.543572             0.365507  0.178065
# 222            0.471853             0.603999             0.429867  0.174132
# 431           -0.316142            -0.206069            -0.362545  0.172238
# 347            0.303507             0.418682             0.270202  0.167936
# 370            0.159408             0.221680             0.103512  0.166879
# 312           -0.151822            -0.025187            -0.191256  0.166069
# 423           -0.165276            -0.055627            -0.199887  0.162502
# 161            0.046337             0.172917             0.012104  0.160813
# 214            0.509745             0.630850             0.470535  0.160315
# 204            0.325494             0.437468             0.287877  0.160164
# 413            0.138998             0.191257             0.084572  0.158343
# 273            0.340075             0.453693             0.296351  0.157342
# 160           -0.040909             0.086131            -0.070371  0.156502
# 206            0.352627             0.288256             0.335379  0.156339
# 379            0.371694             0.486812             0.342840  0.156138
# 320            0.024991             0.107175            -0.025100  0.155709
#
# [20 rows x 26 columns]
